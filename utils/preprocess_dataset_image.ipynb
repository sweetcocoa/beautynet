# %%
import image_preprocess
import sys, os

# %%
import glob

# %%
image_list = glob.glob(os.path.join('../datasets/ImageFolder/', "*.jpg"))

# %%
for path_to_file in sorted(image_list):
    print(path_to_file)
#     if os.path.isfile(path_to_file+"cimg.npy"):
#         continue
    image_preprocess.save_images_state(path_to_file)
# Out:
# ../datasets/ImageFolder/fty1.jpg
# ../datasets/ImageFolder/fty10.jpg
# ../datasets/ImageFolder/fty100.jpg
# ../datasets/ImageFolder/fty1000.jpg
# ../datasets/ImageFolder/fty1001.jpg
# ../datasets/ImageFolder/fty1002.jpg
# ../datasets/ImageFolder/fty1003.jpg
# ../datasets/ImageFolder/fty1004.jpg
# ../datasets/ImageFolder/fty1005.jpg
# ../datasets/ImageFolder/fty1006.jpg
# ../datasets/ImageFolder/fty1007.jpg
# ../datasets/ImageFolder/fty1008.jpg
# ../datasets/ImageFolder/fty1009.jpg
# ../datasets/ImageFolder/fty101.jpg
# ../datasets/ImageFolder/fty1010.jpg
# ../datasets/ImageFolder/fty1011.jpg
# ../datasets/ImageFolder/fty1012.jpg
# ../datasets/ImageFolder/fty1013.jpg
# ../datasets/ImageFolder/fty1014.jpg
# ../datasets/ImageFolder/fty1015.jpg
# ../datasets/ImageFolder/fty1016.jpg
# ../datasets/ImageFolder/fty1017.jpg
# ../datasets/ImageFolder/fty1018.jpg
# ../datasets/ImageFolder/fty1019.jpg
# ../datasets/ImageFolder/fty102.jpg
# ../datasets/ImageFolder/fty1020.jpg
# ...
